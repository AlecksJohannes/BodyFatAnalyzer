# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("BodyFat.xls")
df.head()
# Out:
#    IDNO  BODYFAT  DENSITY  AGE  WEIGHT  HEIGHT  ADIPOSITY  NECK  CHEST  \
# 0     1     12.6   1.0708   23  154.25   67.75       23.7  36.2   93.1
# 1     2      6.9   1.0853   22  173.25   72.25       23.4  38.5   93.6
# 2     3     24.6   1.0414   22  154.00   66.25       24.7  34.0   95.8
# 3     4     10.9   1.0751   26  184.75   72.25       24.9  37.4  101.8
# 4     5     27.8   1.0340   24  184.25   71.25       25.6  34.4   97.3
#
#    ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  FOREARM  WRIST
# 0     85.2   94.5   59.0  37.3   21.9    32.0     27.4   17.1
# 1     83.0   98.7   58.7  37.3   23.4    30.5     28.9   18.2
# 2     87.9   99.2   59.6  38.9   24.0    28.8     25.2   16.6
# 3     86.4  101.2   60.1  37.3   22.8    32.4     29.4   18.2
# 4    100.0  101.9   63.2  42.2   24.0    32.2     27.7   17.7

# %% [markdown]
#  ### What is the best thing to measure if I want to predict how fat.
#
#     Mathmatically, for myself I think to measure the fatness. I would probably use abdomen. Also the correlation between ADIPOSITY AND ABDOMEN seemed to has a really strong connection ( I mean the it has the highest point 0.923 ).

# %%
df["ADIPOSITY"].corr(df["ABDOMEN"])
# Out:
# 0.92388009548111438

# %%
plt.matshow(df.corr())

# %%
def plot_corr_with_labels(df):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(20,20))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr_with_labels(df)

# %%
under_45 = df [ df["AGE"] < 45 ]
over_45 = df [ df["AGE"] >= 45 ]

# %%
u45 = under_45.corr()["ADIPOSITY"]
o45 = over_45.corr()["ADIPOSITY"]

print(o45)
for i in range(df.columns.values.size):
    print(df.columns.values[i], u45[i] - o45[i])
# Out:
# IDNO         0.006517
# BODYFAT      0.749555
# DENSITY     -0.727727
# AGE          0.068950
# WEIGHT       0.891896
# HEIGHT      -0.039037
# ADIPOSITY    1.000000
# NECK         0.793675
# CHEST        0.910941
# ABDOMEN      0.935811
# HIP          0.896765
# THIGH        0.841639
# KNEE         0.672252
# ANKLE        0.542130
# BICEPS       0.717414
# FOREARM      0.582726
# WRIST        0.608106
# Name: ADIPOSITY, dtype: float64
# IDNO 0.058912155828
# BODYFAT -0.0449009637275
# DENSITY 0.028614178193
# AGE 0.0245075581419
# WEIGHT 0.00495104164047
# HEIGHT 0.0351438819609
# ADIPOSITY 0.0
# NECK -0.0306634091241
# CHEST 0.0041758607265
# ABDOMEN -0.02082058084
# HIP -0.0102695058642
# THIGH 0.0321050207493
# KNEE 0.108308425345
# ANKLE -0.0619404301169
# BICEPS 0.0887195538781
# FOREARM -0.0141628005793
# WRIST 0.0365284105745

# %%
list(df.columns.values)
# Out:
# ['IDNO',
#  'BODYFAT',
#  'DENSITY',
#  'AGE',
#  'WEIGHT',
#  'HEIGHT',
#  'ADIPOSITY',
#  'NECK',
#  'CHEST',
#  'ABDOMEN',
#  'HIP',
#  'THIGH',
#  'KNEE',
#  'ANKLE',
#  'BICEPS',
#  'FOREARM',
#  'WRIST']

# %%
## The characteristic as it relates to predicting someone's adiposity that change the most under 45 and over 45 is:
 Characteristic **KNEE** changes by 0.108308425345
